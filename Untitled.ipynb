# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()
# %matplotlib inline

# %%
dados_malaria=pd.read_csv("malaria-parasitemia_subnational_ago (1).csv")

# %%
dados_malaria.head()
# Out:
#             ISO3              Location    DataId  \
# 0  #country+code             #loc+name  #meta+id
# 1            AGO    Stable mesoendemic   1299483
# 2            AGO          Hyperendemic   2691676
# 3            AGO  Instable mesoendemic    867670
# 4            AGO                Luanda   2609454
#
#                              Indicator                 Value  \
# 0                      #indicator+name  #indicator+value+num
# 1  Malaria prevalence according to RDT                  26.4
# 2  Malaria prevalence according to RDT                  30.6
# 3  Malaria prevalence according to RDT                  21.1
# 4  Malaria prevalence according to RDT                   6.2
#
#               Precision DHS_CountryCode    CountryName  SurveyYear  \
# 0  #indicator+precision             NaN  #country+name  #date+year
# 1                     1              AO         Angola        2006
# 2                     1              AO         Angola        2006
# ...

# %%
dados_malaria.Location.unique()
# Out:
# array(['#loc+name', 'Stable mesoendemic', 'Hyperendemic',
#        'Instable mesoendemic', 'Luanda', 'Cabinda         ',
#        'Zaire           ', 'Uíge            ', 'Luanda          ',
#        'Cuanza Norte    ', 'Cuanza Sul      ', 'Malanje         ',
#        'Lunda Norte     ', 'Benguela        ', 'Huambo          ',
#        'Bié             ', 'Moxico          ', 'Cuando Cubango  ',
#        'Namibe          ', 'Huíla           ', 'Cunene          ',
#        'Lunda Sul       ', 'Bengo           '], dtype=object)

# %%
dados_malaria=dados_malaria.groupby("Location")

# %%
dados_malaria.groups
# Out:
# {'#loc+name': Int64Index([0], dtype='int64'),
#  'Bengo           ': Int64Index([54, 72, 90], dtype='int64'),
#  'Benguela        ': Int64Index([45, 63, 81], dtype='int64'),
#  'Bié             ': Int64Index([47, 65, 83], dtype='int64'),
#  'Cabinda         ': Int64Index([37, 55, 73], dtype='int64'),
#  'Cuando Cubango  ': Int64Index([49, 67, 85], dtype='int64'),
#  'Cuanza Norte    ': Int64Index([41, 59, 77], dtype='int64'),
#  'Cuanza Sul      ': Int64Index([42, 60, 78], dtype='int64'),
#  'Cunene          ': Int64Index([52, 70, 88], dtype='int64'),
#  'Huambo          ': Int64Index([46, 64, 82], dtype='int64'),
#  'Huíla           ': Int64Index([51, 69, 87], dtype='int64'),
#  'Hyperendemic': Int64Index([2, 6, 10, 14, 18, 22, 26, 30, 34], dtype='int64'),
#  'Instable mesoendemic': Int64Index([3, 7, 11, 15, 19, 23, 27, 31, 35], dtype='int64'),
#  'Luanda': Int64Index([4, 8, 12, 16, 20, 24, 28, 32, 36], dtype='int64'),
#  'Luanda          ': Int64Index([40, 58, 76], dtype='int64'),
# ...
